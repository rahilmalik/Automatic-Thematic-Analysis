# %% [markdown]
# ### Installing BERTopic and importing all necessary libraries

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.2-py2.py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.25.2)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 15.3 MB/s eta 0:00:00
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.4)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Downloading Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.41.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.23.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 42.2 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, cython, nvidia-cusparse-cu12, nvidia-cudnn-cu12, pynndescent, nvidia-cusolver-cu12, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.10
#     Uninstalling Cython-3.0.10:
#       Successfully uninstalled Cython-3.0.10
# Successfully installed bertopic-0.16.2 cython-0.29.37 hdbscan-0.8.37 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pynndescent-0.5.13 sentence-transformers-3.0.1 umap-learn-0.5.6

# %%
import numpy as np
import pandas as pd
from bertopic import BERTopic
import nltk
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# ### Reading the excel files

# %%
data = pd.read_excel("/content/drive/MyDrive/DissertationProject/Data/NSS2023_BrunelStudentComments_published2023-10-11.xlsx",header=[2])
data2023 = pd.read_excel("/content/drive/MyDrive/DissertationProject/Data/NSS2023_BrunelStudentComments_published2023-10-11.xlsx",header=[2])
data2022 = pd.read_excel("/content/drive/MyDrive/DissertationProject/Data/NSS2022_StudentComments_ALL_pub2022_0922.xlsx",header=[3])
data2021 = pd.read_excel("/content/drive/MyDrive/DissertationProject/Data/NSS2021_ StudentComments_ALL.xlsx",header=[3],sheet_name="NSS2021Comments")


data2023 = data2023[['Positive comments','Negative comments']]
data2023 = data2023.rename(columns={'Positive comments': 'Positive comment', 'Negative comments': 'Negative comment'})
data2022 = data2022[['Positive comment','Negative comment']]
data2021 = data2021[['Positive comment','Negative comment']]

# %%
combined_data = pd.concat([data2021, data2022, data2023])
#combined_data.head()
#combined_data.tail()
#data = combined_data

# To switch to data of year 202n
data = data2023

# %%
data.info()
data.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Positive comment  920 non-null    object
#  1   Negative comment  870 non-null    object
# dtypes: object(2)
# memory usage: 16.1+ KB
# Positive comment    102
# Negative comment    152
# dtype: int64

# %%
data = data.dropna()

# %%
docs_pos = data['Positive comment']
docs_neg = data['Negative comment']
#docs = pd.concat([docs_pos, docs_neg])

# %%
docs_pos.tail()
# Out:
# 1015    It was good that along with the accounting deg...
# 1016    Tutors are very good in explaining and making ...
# 1018    The involvement of staff from industry was vit...
# 1019    Teaching staff wanted to give us extra help an...
# 1020    The 12-month placements were the best parts of...
# Name: Positive comment, dtype: object

# %% [markdown]
# ### Preprocessing

# %%
#Preprocessing


stop = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemma = WordNetLemmatizer

# To remove numbers
def remove_num(text):
    output = re.sub(r'\d+', '', text )
    return output

# To unify whitespaces
def unify_whitespaces(text):
    cleaned_string = re.sub(' +', ' ', text )
    return cleaned_string

# To remove punctuation
def remove_punctuation(text):
    result = "".join(u for u in text if u not in ("?", ".", ";", ":",  "!",'"',',') )
    return result

# To remove stopwords
def remove_stopwords(text):
  text = [word.lower() for word in text.split() if word.lower() not in stop ]
  return ' '.join(text)

# To Apply Stemming
def Stemming(text):
    stem = []
    stopword = stopwords.words('english')
    snowball_stemmer = SnowballStemmer('english')
    word_tokens = nltk.word_tokenize(text)
    stemmed_word = [ snowball_stemmer.stem(word) for word in word_tokens ]
    stem = ' '.join(stemmed_word)
    return stem

# To Apply Lemmatizing
def Lemmatizing(text):
    lemmatizer = WordNetLemmatizer()
    stopword = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)

    lemmatized_words = [lemmatizer.lemmatize(word) for word in word_tokens if word.lower() not in stopword]
    lemmatized_text = ' '.join(lemmatized_words)
    return lemmatized_text

# %%
#Applying all the cleaning functions
def cleaning(data):
    data_processed = data.copy()
    data_processed = data_processed.apply(remove_num)
    data_processed = data_processed.apply(remove_punctuation)
    data_processed = data_processed.apply(unify_whitespaces)
    data_processed = data_processed.apply(remove_stopwords)
    data_processed = data_processed.drop_duplicates()
    #data_processed = data_processed.apply(Stemming)
    data_processed = data_processed.apply(Lemmatizing)
    return data_processed

docs_pos_processed = cleaning(docs_pos)
docs_neg_processed = cleaning(docs_neg)

# %%
docs_pos_processed.head()
# Out:
# 0                           practical project engaging
# 1    many professor passionate subject matter many ...
# 2    campus equipment good reliable tema 's project...
# 3    teaching staff content good level amount infor...
# 4                great exam online level stress person
# Name: Positive comment, dtype: object

# %% [markdown]
# #### Choose your embedding model

# %%
#model = BERTopic(embedding_model="all-mpnet-base-v2")
model = BERTopic(embedding_model="all-MiniLM-L12-v2")

# %% [markdown]
# Fitting the model on the documents

# %%
topics, probs = model.fit_transform(docs_pos_processed)
topic_labels = model.generate_topic_labels(topic_prefix=False, separator=' - ')
model.set_topic_labels(topic_labels)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                        Name  \
# 0      -1    308             -1_lecturer_student_good_course
# 1       0     67             0_staff_teaching_helpful_always
# 2       1     65             1_course_module_lecture_seminar
# 3       2     39            2_resource_online_library_access
# 4       3     32               3_brunel_life_experience_also
# 5       4     30       4_everything_fine_experience_positive
# 6       5     26           5_mental_health_support_wellbeing
# 7       6     26                  6_tutor_personal_help_talk
# 8       7     23     7_engaging_lecturer_lecture_interactive
# 9       8     18         8_opportunity_work_valuable_allowed
# 10      9     18             9_email_reply_lecturer_question
# 11     10     16          10_lecturer_enjoyable_met_actually
# 12     11     15              11_teacher_teaching_great_good
# 13     12     15  12_supervisor_dissertation_feedback_leader
# 14     13     15             13_teacher_help_respond_contact
# 15     14     15         14_placement_industry_educator_year
# 16     15     13    15_facility_software_accessible_hardware
# 17     16     10             16_engaging_interesting_fun_yet
#
#                               CustomName  \
# 0              lecturer - student - good
# 1             staff - teaching - helpful
# 2              course - module - lecture
# 3            resource - online - library
# 4             brunel - life - experience
# 5         everything - fine - experience
# 6              mental - health - support
# 7                tutor - personal - help
# 8          engaging - lecturer - lecture
# 9          opportunity - work - valuable
# 10              email - reply - lecturer
# 11            lecturer - enjoyable - met
# 12            teacher - teaching - great
# 13  supervisor - dissertation - feedback
# 14              teacher - help - respond
# 15       placement - industry - educator
# 16      facility - software - accessible
# 17          engaging - interesting - fun
#
#                                        Representation  \
# 0   [lecturer, student, good, course, really, well...
# 1   [staff, teaching, helpful, always, supportive,...
# 2   [course, module, lecture, seminar, well, learn...
# 3   [resource, online, library, access, lecture, g...
# 4   [brunel, life, experience, also, student, desi...
# 5   [everything, fine, experience, positive, nothi...
# 6   [mental, health, support, wellbeing, service, ...
# 7   [tutor, personal, help, talk, advice, support,...
# 8   [engaging, lecturer, lecture, interactive, int...
# 9   [opportunity, work, valuable, allowed, skill, ...
# 10  [email, reply, lecturer, question, quick, quer...
# 11  [lecturer, enjoyable, met, actually, people, f...
# 12  [teacher, teaching, great, good, liveable, slo...
# 13  [supervisor, dissertation, feedback, leader, p...
# 14  [teacher, help, respond, contact, needing, nee...
# 15  [placement, industry, educator, year, link, pp...
# 16  [facility, software, accessible, hardware, wor...
# 17  [engaging, interesting, fun, yet, entertaining...
#
#                                   Representative_Docs
# 0   [teaching thorough considerate throughout staf...
# 1   [teaching staff friendly helpful, teaching sta...
# 2   [content within module great always new thing ...
# 3   [everything positive course easy access teache...
# 4   [teaching staff game department incredible 're...
# 5   [everything good, everything seems fine conten...
# 6   [mental health service really good, mental hea...
# 7   [conversation discussion personal tutor crucia...
# 8   [staff always help lecturer lecture interactiv...
# 9   [learned lot valuable skill developed understa...
# 10  [welcoming staff reply email rather good, staf...
# 11  [great professor lecturer supervisor enjoyable...
# 12  [great campus great teacher, teacher good, tea...
# 13  [seminar leader help dissertation fantastic we...
# 14  [teacher respond well efficient needing help, ...
# 15  [formula student teaching staff industry link ...
# 16  [teaching staff helpful software/hardware faci...
# 17  [good content delivered fun engaging, engaging...

# %%
model.get_topic(2)
# Out:
# [('resource', 0.09514751650078064),
#  ('online', 0.09257825174732207),
#  ('library', 0.06383516870557547),
#  ('access', 0.05047936916673139),
#  ('lecture', 0.046971741056428526),
#  ('good', 0.04336769676289636),
#  ('recording', 0.04328156478871801),
#  ('useful', 0.041620941933462816),
#  ('brightspace', 0.03938694003609443),
#  ('easy', 0.03927956255995771)]

# %%
model.get_representative_docs(2)
# Out:
# ['everything positive course easy access teacher online resource',
#  'library resource good',
#  'year online even hybrid module online in-person come realise advantage particularly people physical disability mobility problem except able properly use lab due pandemic would good learning opportunity physically campus may good able interact another location live lecture useful expect come serious health issue accident final year come miss able participate interactive live online class particularly low-mobility day like learning get recording lecture despite able message lecturer subject lecture really miss feeling actually time lecture interacting peer & lecturer many lecturer kind patient really appreciate really great many event opportunity present probably would liked work worry spend time besides attending full-time university missed many workshop career event really wanted go']

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9062e9da-8caf-4a7f-b5d3-fbd29b47bd82" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9062e9da-8caf-4a7f-b5d3-fbd29b47bd82")) {                    Plotly.newPlot(                        "9062e9da-8caf-4a7f-b5d3-fbd29b47bd82",                        [{"customdata":[[0,"staff | teaching | helpful | always | supportive",67],[1,"course | module | lecture | seminar | well",65],[2,"resource | online | library | access | lecture",39],[3,"brunel | life | experience | also | student",32],[4,"everything | fine | experience | positive | nothing",30],[5,"mental | health | support | wellbeing | service",26],[6,"tutor | personal | help | talk | advice",26],[7,"engaging | lecturer | lecture | interactive | interaction",23],[8,"opportunity | work | valuable | allowed | skill",18],[9,"email | reply | lecturer | question | quick",18],[10,"lecturer | enjoyable | met | actually | people",16],[11,"teacher | teaching | great | good | liveable",15],[12,"supervisor | dissertation | feedback | leader | project",15],[13,"teacher | help | respond | contact | needing",15],[14,"placement | industry | educator | year | link",15],[15,"facility | software | accessible | hardware | workshop",13],[16,"engaging | interesting | fun | yet | entertaining",10]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[67,65,39,32,30,26,26,23,18,18,16,15,15,15,15,13,10],"sizemode":"area","sizeref":0.041875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[24.06957244873047,3.185302734375,3.6455953121185303,2.0252087116241455,-6.349665641784668,2.189793109893799,13.699752807617188,-5.235095977783203,1.7000004053115845,-4.906864166259766,-5.640697479248047,-6.156376838684082,24.349815368652344,13.43637466430664,1.7347818613052368,3.821481943130493,2.8444559574127197],"xaxis":"x","y":[-5.227231979370117,-2.9093713760375977,-3.40170955657959,-2.308197259902954,10.236056327819824,-2.590665340423584,0.3116481602191925,10.069986343383789,-2.07116961479187,10.43395709991455,9.83958911895752,9.892271995544434,-5.473780632019043,0.04829871654510498,-2.7190444469451904,-3.823622465133667,-3.289764404296875],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colo ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fbd30b83-8347-435c-acd5-5ead3ab3e965" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbd30b83-8347-435c-acd5-5ead3ab3e965")) {                    Plotly.newPlot(                        "fbd30b83-8347-435c-acd5-5ead3ab3e965",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.046839675868051545,0.049057632788130454,0.05523618723828055,0.08395342301094946,0.13437221645251735],"y":["supportive  ","always  ","helpful  ","teaching  ","staff  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03657605832096593,0.040843169761423964,0.044956162615574315,0.05080472899200619,0.06980282935617546],"y":["well  ","seminar  ","lecture  ","module  ","course  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.046971741056428526,0.05047936916673139,0.06383516870557547,0.09257825174732207,0.09514751650078064],"y":["lecture  ","access  ","library  ","online  ","resource  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.027438844944501727,0.027829708755481825,0.029499830348118632,0.03399982241947336,0.03632086774728758],"y":["student  ","also  ","experience  ","life  ","brunel  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.16024763689435487,0.18183422870969815,0.195932767432336,0.22697890511584184,0.30598586161039987],"y":["nothing  ","positive  ","experience  ","fine  ","everything  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.05407519146804997,0.056200876458321,0.06763935106258316,0.09432509063186005,0.11231135538422653],"y":["service  ","wellbeing  ","support  ","health  ","mental  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.05899162175545654,0.06054082468469346,0.061716182246548755,0.15040789264612142,0.2548576687250953],"y":["advice  ","talk  ","help  ","personal  ","tutor  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.07484306540431125,0.07818685754890128,0.11281134439114154,0.11528980452242607,0.11633247214482892],"y":["interaction  ","interactive  ","lecture  ","lecturer  ","engaging  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1    308
# 5       0     67
# 1       1     65
# 9       2     39
# 4       3     32
# 2       4     30
# 13      5     26
# 14      6     26
# 10      7     23
# 3       8     18
# 11      9     18
# 8      10     16
# 7      11     15
# 15     12     15
# 16     13     15
# 17     14     15
# 6      15     13
# 12     16     10

# %% [markdown]
# ## For Negative Comments

# %%
#model_neg = BERTopic(embedding_model="all-mpnet-base-v2")
model_neg = BERTopic(embedding_model="all-MiniLM-L12-v2")
topics_neg, probs_neg = model_neg.fit_transform(docs_neg_processed)
topic_labels = model_neg.generate_topic_labels(topic_prefix=False, separator=' - ')
model_neg.set_topic_labels(topic_labels)
model_neg.get_topic_info()
# Out:
#     Topic  Count                                        Name  \
# 0      -1    243               -1_student_year_course_module
# 1       0    109          0_feedback_assessment_marking_exam
# 2       1     84         1_lecturer_lecture_seminar_engaging
# 3       2     50             2_placement_staff_student_would
# 4       3     32                3_module_year_work_available
# 5       4     31                 4_covid_experience_year_due
# 6       5     28                  5_negative_nothing_ca_sure
# 7       6     26               6_online_book_tuition_lecture
# 8       7     24       7_timetable_time_timetabling_deadline
# 9       8     22        8_organisation_course_organised_club
# 10      9     18  9_accommodation_facility_campus_university
# 11     10     17                10_email_reply_respond_staff
# 12     11     16            11_mental_health_support_service
# 13     12     14           12_brief_lecture_lecturer_example
# 14     13     13               13_group_work_project_ethical
# 15     14     11                  14_slide_lecture_help_word
# 16     15     10            15_society_group_social_activity
#
#                            CustomName  \
# 0             student - year - course
# 1     feedback - assessment - marking
# 2        lecturer - lecture - seminar
# 3         placement - staff - student
# 4                module - year - work
# 5           covid - experience - year
# 6             negative - nothing - ca
# 7             online - book - tuition
# 8      timetable - time - timetabling
# 9   organisation - course - organised
# 10  accommodation - facility - campus
# 11            email - reply - respond
# 12          mental - health - support
# 13         brief - lecture - lecturer
# 14             group - work - project
# 15             slide - lecture - help
# 16           society - group - social
#
#                                        Representation  \
# 0   [student, year, course, module, time, teaching...
# 1   [feedback, assessment, marking, exam, mark, as...
# 2   [lecturer, lecture, seminar, engaging, interac...
# 3   [placement, staff, student, would, year, cours...
# 4   [module, year, work, available, course, also, ...
# 5   [covid, experience, year, due, feel, first, on...
# 6   [negative, nothing, ca, sure, none, really, pa...
# 7   [online, book, tuition, lecture, learning, yea...
# 8   [timetable, time, timetabling, deadline, march...
# 9   [organisation, course, organised, club, year, ...
# 10  [accommodation, facility, campus, university, ...
# 11  [email, reply, respond, staff, never, sometime...
# 12  [mental, health, support, service, funding, pr...
# 13  [brief, lecture, lecturer, example, structure,...
# 14  [group, work, project, ethical, prayer, one, m...
# 15  [slide, lecture, help, word, reading, depth, n...
# 16  [society, group, social, activity, joined, uni...
#
#                                   Representative_Docs
# 0   [course always felt slow start ( beginning ter...
# 1   [feedback really bad & professor take time mar...
# 2   [sometimes lecture long engaging, lecturer eng...
# 3   [staff awful response either get non-helpful r...
# 4   [certain module international investment arbit...
# 5   [experience really good covid-, get full exper...
# 6   [negative, nothing particularly negative, noth...
# 7   [online study, couple lecturer well prepared w...
# 8   [everything including email timetabling etc on...
# 9   [issue time organisation wise would hear lot s...
# 10  [paying accommodation first year whilst club c...
# 11  [teacher never responded via email multiple at...
# 12  [support mental health ever, mental health ser...
# 13  [understand something example coursework & lec...
# 14  [however time witnessed suffered racial profil...
# 15  [lecturer respond email well like lecture slid...
# 16  [socialising online class hard felt like part ...

# %%
model_neg.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="986c2f18-2ea7-4df4-b22b-2afafe93b83b" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("986c2f18-2ea7-4df4-b22b-2afafe93b83b")) {                    Plotly.newPlot(                        "986c2f18-2ea7-4df4-b22b-2afafe93b83b",                        [{"customdata":[[0,"feedback | assessment | marking | exam | mark",109],[1,"lecturer | lecture | seminar | engaging | interactive",84],[2,"placement | staff | student | would | year",50],[3,"module | year | work | available | course",32],[4,"covid | experience | year | due | feel",31],[5,"negative | nothing | ca | sure | none",28],[6,"online | book | tuition | lecture | learning",26],[7,"timetable | time | timetabling | deadline | march",24],[8,"organisation | course | organised | club | year",22],[9,"accommodation | facility | campus | university | first",18],[10,"email | reply | respond | staff | never",17],[11,"mental | health | support | service | funding",16],[12,"brief | lecture | lecturer | example | structure",14],[13,"group | work | project | ethical | prayer",13],[14,"slide | lecture | help | word | reading",11],[15,"society | group | social | activity | joined",10]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[109,84,50,32,31,28,26,24,22,18,17,16,14,13,11,10],"sizemode":"area","sizeref":0.068125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[16.17047119140625,1.0808072090148926,16.22614288330078,1.8198662996292114,14.078909873962402,13.754337310791016,0.8094750642776489,16.024906158447266,15.73931884765625,14.489766120910645,15.243382453918457,15.817243576049805,1.5111970901489258,15.730127334594727,1.1993749141693115,15.754451751708984],"xaxis":"x","y":[-2.7047367095947266,15.079011917114258,-3.1317689418792725,14.46366024017334,-1.3465319871902466,-0.9915392994880676,14.847114562988281,-3.984135866165161,-4.007871150970459,-1.7503414154052734,-3.2027320861816406,-3.0596766471862793,14.70438003540039,-5.047730445861816,15.343646049499512,-4.677437782287598],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"] ...

# %%
model_neg.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="565a1bae-93cf-43f3-a10b-54f14b803c59" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("565a1bae-93cf-43f3-a10b-54f14b803c59")) {                    Plotly.newPlot(                        "565a1bae-93cf-43f3-a10b-54f14b803c59",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.04284875131612623,0.04905746756814208,0.049931245723399825,0.05604458846443931,0.09021392441691345],"y":["mark  ","exam  ","marking  ","assessment  ","feedback  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03845999111263579,0.055969577985054406,0.07094467580571537,0.07802809544908552,0.07965995687018808],"y":["interactive  ","engaging  ","seminar  ","lecture  ","lecturer  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019703881958400057,0.020436394359856103,0.024687899952837246,0.03692425874786061,0.06891485441556436],"y":["year  ","would  ","student  ","staff  ","placement  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.021616009255725547,0.024280544615794136,0.030775281339284453,0.03844888434776962,0.059411525418275976],"y":["course  ","available  ","work  ","year  ","module  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.04113574247932979,0.04347160903890405,0.06364302172301867,0.06832132613980833,0.21179611103340584],"y":["feel  ","due  ","year  ","experience  ","covid  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.12483996181335581,0.1309762510887962,0.134654332875686,0.32186586510214465,0.5377476995106948],"y":["none  ","sure  ","ca  ","nothing  ","negative  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.06500488603125752,0.06825268519749376,0.08233109183722893,0.08576791269619866,0.2647493982194392],"y":["learning  ","lecture  ","tuition  ","book  ","online  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0530157713135782,0.055224322348423546,0.06712798601731694,0.06748487023306084,0.08038787352057385],"y":["march  ","deadline  ","timetabling  ","time  ","timetable  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0. ...
